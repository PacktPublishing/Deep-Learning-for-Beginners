# %% [markdown]
# # Final Remarks on The Future of Deep Learning

# %% [markdown]
# ##Looking for Advanced Topics in Deep Learning

# %% [markdown]
# ###Deep Reinforcement Learning

# %%
# !pip install -U dopamine-rl
# Out:
# Collecting dopamine-rl
#   Downloading https://files.pythonhosted.org/packages/ea/4e/adc7e7d1d096debfcd89fe5b0825e4efcbe9c9cd2c73358dcc7ce35b4334/dopamine_rl-3.1.7-py3-none-any.whl (117kB)
#      |████████████████████████████████| 122kB 7.5MB/s
# Collecting pygame>=1.9.2
#   Downloading https://files.pythonhosted.org/packages/8e/24/ede6428359f913ed9cd1643dd5533aefeb5a2699cc95bea089de50ead586/pygame-1.9.6-cp36-cp36m-manylinux1_x86_64.whl (11.4MB)
#      |████████████████████████████████| 11.4MB 11.9MB/s
# Requirement already satisfied, skipping upgrade: jaxlib>=0.1.51 in /usr/local/lib/python3.6/dist-packages (from dopamine-rl) (0.1.52)
# Collecting absl-py>=0.9.0
#   Downloading https://files.pythonhosted.org/packages/b9/07/f69dd3367368ad69f174bfe426a973651412ec11d48ec05c000f19fe0561/absl_py-0.10.0-py3-none-any.whl (127kB)
#      |████████████████████████████████| 133kB 46.6MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.16.4 in /usr/local/lib/python3.6/dist-packages (from dopamine-rl) (1.18.5)
# Collecting tf-slim>=1.0
#   Downloading https://files.pythonhosted.org/packages/02/97/b0f4a64df018ca018cc035d44f2ef08f91e2e8aa67271f6f19633a015ff7/tf_slim-1.1.0-py2.py3-none-any.whl (352kB)
#      |████████████████████████████████| 358kB 49.5MB/s
# Requirement already satisfied, skipping upgrade: pandas>=0.24.2 in /usr/local/lib/python3.6/dist-packages (from dopamine-rl) (1.0.5)
# Requirement already satisfied, skipping upgrade: jax>=0.1.72 in /usr/local/lib/python3.6/dist-packages (from dopamine-rl) (0.1.75)
# Requirement already satisfied, skipping upgrade: gin-config>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from dopamine-rl) (0.3.0)
# Requirement already satisfied, skipping upgrade: tensorflow>=2.2.0 in /usr/local/lib/python3.6/dist-packages (from dopamine-rl) (2.3.0)
# Requirement already satisfied, skipping upgrade: Pillow>=7.0.0 in /usr/local/lib/python3.6/dist-packages (from dopamine-rl) (7.0.0)
# Requirement already satisfied, skipping upgrade: opencv-python>=3.4.8.29 in /usr/local/lib/python3.6/dist-packages (from dopamine-rl) (4.1.2.30)
# Requirement already satisfied, skipping upgrade: gym[atari]>=0.13.1 in /usr/local/lib/python3.6/dist-packages (from dopamine-rl) (0.17.2)
# Collecting flax>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/91/b8/ab292e363cb8758a391541b7942f175f79b3ac06a477dd4495de7c8c91f6/flax-0.2.0-py3-none-any.whl (84kB)
#      |████████████████████████████████| 92kB 11.3MB/s
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from jaxlib>=0.1.51->dopamine-rl) (1.4.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from absl-py>=0.9.0->dopamine-rl) (1.15.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.2->dopamine-rl) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24.2->dopamine-rl) (2018.9)
# Requirement already satisfied, skipping upgrade: opt-einsum in /usr/local/lib/python3.6/dist-packages (from jax>=0.1.72->dopamine-rl) (3.3.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->dopamine-rl) (3.12.4)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->dopamine-rl) (1.31.0)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->dopamine-rl) (1.1.0)
# Requirement already satisfied, skipping upgrade: keras-preprocessing<1.2,>=1.1.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->dopamine-rl) (1.1.2)
# Requirement already satisfied, skipping upgrade: tensorboard<3,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->dopamine-rl) (2.3.0)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->dopamine-rl) (1.12.1)
# Requirement already satisfied, skipping upgrade: astunparse==1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->dopamine-rl) (1.6.3)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->dopamine-rl) (0.35.1)
# Requirement already satisfied, skipping upgrade: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->dopamine-rl) (0.3.3)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<2.4.0,>=2.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->dopamine-rl) (2.3.0)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->dopamine-rl) (0.2.0)
# Requirement already satisfied, skipping upgrade: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow>=2.2.0->dopamine-rl) (2.10.0)
# Requirement already satisfied, skipping upgrade: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]>=0.13.1->dopamine-rl) (1.5.0)
# Requirement already satisfied, skipping upgrade: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym[atari]>=0.13.1->dopamine-rl) (1.3.0)
# Requirement already satisfied, skipping upgrade: atari-py~=0.2.0; extra == "atari" in /usr/local/lib/python3.6/dist-packages (from gym[atari]>=0.13.1->dopamine-rl) (0.2.6)
# Requirement already satisfied, skipping upgrade: matplotlib in /usr/local/lib/python3.6/dist-packages (from flax>=0.2.0->dopamine-rl) (3.2.2)
# Requirement already satisfied, skipping upgrade: msgpack in /usr/local/lib/python3.6/dist-packages (from flax>=0.2.0->dopamine-rl) (1.0.0)
# Requirement already satisfied, skipping upgrade: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from flax>=0.2.0->dopamine-rl) (0.7)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.9.2->tensorflow>=2.2.0->dopamine-rl) (49.6.0)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (1.17.2)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (0.4.1)
# Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (1.7.0)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (1.0.1)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (3.2.2)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (2.23.0)
# Requirement already satisfied, skipping upgrade: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym[atari]>=0.13.1->dopamine-rl) (0.16.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib->flax>=0.2.0->dopamine-rl) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->flax>=0.2.0->dopamine-rl) (1.2.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib->flax>=0.2.0->dopamine-rl) (2.4.7)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (0.2.8)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (4.1.1)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (4.6)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (1.3.0)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (1.7.0)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (2020.6.20)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (1.24.3)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (0.4.8)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (3.1.0)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow>=2.2.0->dopamine-rl) (3.1.0)
# ERROR: tensorflow-metadata 0.23.0 has requirement absl-py<0.9,>=0.7, but you'll have absl-py 0.10.0 which is incompatible.
# Installing collected packages: pygame, absl-py, tf-slim, flax, dopamine-rl
#   Found existing installation: absl-py 0.8.1
#     Uninstalling absl-py-0.8.1:
#       Successfully uninstalled absl-py-0.8.1
#   Found existing installation: dopamine-rl 1.0.5
#     Uninstalling dopamine-rl-1.0.5:
#       Successfully uninstalled dopamine-rl-1.0.5
# Successfully installed absl-py-0.10.0 dopamine-rl-3.1.7 flax-0.2.0 pygame-1.9.6 tf-slim-1.1.0

# %%
# !gsutil -q -m cp -R gs://download-dopamine-rl/colab/samples/rainbow/SpaceInvaders_v4/checkpoints/tf_ckpt-199.data-00000-of-00001 ./
# !gsutil -q -m cp -R gs://download-dopamine-rl/colab/samples/rainbow/SpaceInvaders_v4/checkpoints/tf_ckpt-199.index ./
# !gsutil -q -m cp -R gs://download-dopamine-rl/colab/samples/rainbow/SpaceInvaders_v4/checkpoints/tf_ckpt-199.meta ./

# %%
from dopamine.utils import example_viz_lib
example_viz_lib.run(agent='rainbow', game='SpaceInvaders', num_steps=768,
                    root_dir='./', restore_ckpt='./tf_ckpt-199',
                    use_legacy_checkpoint=True)
# Out:
# INFO:tensorflow:Restoring parameters from ./tf_ckpt-199
# INFO:tensorflow:Restoring parameters from ./tf_ckpt-199
# /usr/local/lib/python3.6/dist-packages/dopamine/utils/line_plotter.py:99: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
#   self.plot.set_xlim(min_xlim, max_xlim)

# %%
from IPython.display import Image
frame_number = 540
image_file = '/content/agent_viz/SpaceInvaders/rainbow/images/frame_{:06d}.png'.format(frame_number)
Image(image_file)

# %%
import base64
from IPython.display import HTML
base_dir = '/content/agent_viz/SpaceInvaders/rainbow'
video = open('{}/images/video.mp4'.format(base_dir), 'rb').read()
encoded = base64.b64encode(video)
HTML(data='''<video alt="test" controls>
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii')))
# Out:
# <video alt="test" controls>
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
