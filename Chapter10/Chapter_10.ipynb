# %% [markdown]
# #Restricted Boltzmann Machines

# %%
# %tensorflow_version 2.x

# %% [markdown]
# ##Learning data representations with RBMs

# %%
from sklearn.neural_network import BernoulliRBM
from tensorflow.keras.datasets import mnist
import numpy as np

(x_train, y_train), (x_test, y_test) = mnist.load_data()

image_size = x_train.shape[1]
original_dim = image_size * image_size
x_train = np.reshape(x_train, [-1, original_dim])
x_test = np.reshape(x_test, [-1, original_dim])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

rbm = BernoulliRBM(verbose=True)

rbm.n_components = 100
rbm.fit(x_train)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# [BernoulliRBM] Iteration 1, pseudo-likelihood = -105.59, time = 10.39s
# [BernoulliRBM] Iteration 2, pseudo-likelihood = -102.69, time = 13.24s
# [BernoulliRBM] Iteration 3, pseudo-likelihood = -101.12, time = 33.75s
# [BernoulliRBM] Iteration 4, pseudo-likelihood = -101.09, time = 32.61s
# [BernoulliRBM] Iteration 5, pseudo-likelihood = -98.59, time = 14.28s
# [BernoulliRBM] Iteration 6, pseudo-likelihood = -98.21, time = 14.20s
# [BernoulliRBM] Iteration 7, pseudo-likelihood = -98.50, time = 19.45s
# [BernoulliRBM] Iteration 8, pseudo-likelihood = -97.30, time = 25.04s
# [BernoulliRBM] Iteration 9, pseudo-likelihood = -96.88, time = 11.12s
# [BernoulliRBM] Iteration 10, pseudo-likelihood = -99.02, time = 11.09s
# BernoulliRBM(batch_size=10, learning_rate=0.1, n_components=100, n_iter=10,
#              random_state=None, verbose=True)

# %%
r = rbm.transform(x_test)

# %%
import matplotlib.pyplot as plt
import umap

y_ = list(map(int, y_test))
X_ = rbm.transform(x_test)

X_ = umap.UMAP().fit_transform(X_)

plt.figure(figsize=(10,8))
plt.title('UMAP of 100 RBM Learned Components on MNIST')
plt.scatter(X_[:,0], X_[:,1], s=5.0, c=y_, alpha=0.75, cmap='tab10')
plt.xlabel('$z_1$')
plt.ylabel('$z_2$')
plt.colorbar()

# %%
v = rbm.components_

# %%
plt.figure(figsize=(10, 9.5))
for i, comp in enumerate(v):
    plt.subplot(10, 10, i + 1)
    plt.imshow(comp.reshape((28, 28)), cmap=plt.cm.gray_r,
               interpolation='nearest')
    plt.xticks(())
    plt.yticks(())
plt.subplots_adjust(0.08, 0.02, 0.92, 0.85, 0.08, 0.23)
plt.savefig('ch.10.rbm.100.components.mnist.png', bbox_inches='tight', dpi=350)

# %%
plt.figure(figsize=(10, 9.5))
cnt = 1
for i in range(10):
  X_ = x_test[i]
  for j in range(10):
    plt.subplot(10, 10, cnt)
    plt.imshow(X_.reshape((28, 28)), cmap='gray')
    X_ = rbm.gibbs(X_)
    plt.xticks(())
    plt.yticks(())
    cnt += 1
plt.subplots_adjust(0.08, 0.02, 0.92, 0.85, 0.08, 0.23)
plt.savefig('ch.10.rbm.100.gibs.mnist.png', bbox_inches='tight', dpi=350)

# %% [markdown]
# ##Comparing RBMs and AEs

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

inpt_dim = 28*28    # 784 dimensions
ltnt_dim = 100      # 100 components

inpt_vec = Input(shape=(inpt_dim,))
encoder = Dense(ltnt_dim, activation='sigmoid') (inpt_vec)
latent_ncdr = Model(inpt_vec, encoder)
decoder = Dense(inpt_dim, activation='sigmoid') (encoder)
autoencoder = Model(inpt_vec, decoder)

autoencoder.compile(loss='binary_crossentropy', optimizer='adam')
autoencoder.fit(x_train, x_train, epochs=200, batch_size=1000)
# Out:
# Epoch 1/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.3782
# Epoch 2/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.2681
# Epoch 3/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.2626
# Epoch 4/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.2550
# Epoch 5/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.2436
# Epoch 6/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.2311
# Epoch 7/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.2196
# Epoch 8/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.2094
# Epoch 9/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.2008
# Epoch 10/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1937
# Epoch 11/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1875
# Epoch 12/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1819
# Epoch 13/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1766
# Epoch 14/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1716
# Epoch 15/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1669
# Epoch 16/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1625
# Epoch 17/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1584
# Epoch 18/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1546
# Epoch 19/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1511
# Epoch 20/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1477
# Epoch 21/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1446
# Epoch 22/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1416
# Epoch 23/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1388
# Epoch 24/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1362
# Epoch 25/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1337
# Epoch 26/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1314
# Epoch 27/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1293
# Epoch 28/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1272
# Epoch 29/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1253
# Epoch 30/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1234
# Epoch 31/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1217
# Epoch 32/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1201
# Epoch 33/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1185
# Epoch 34/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1171
# Epoch 35/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1156
# Epoch 36/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1143
# Epoch 37/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1130
# Epoch 38/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1118
# Epoch 39/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1107
# Epoch 40/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1096
# Epoch 41/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1085
# Epoch 42/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1075
# Epoch 43/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1066
# Epoch 44/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1057
# Epoch 45/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1048
# Epoch 46/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1040
# Epoch 47/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1032
# Epoch 48/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1024
# Epoch 49/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1017
# Epoch 50/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1010
# Epoch 51/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1004
# Epoch 52/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0998
# Epoch 53/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0992
# Epoch 54/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0986
# Epoch 55/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0980
# Epoch 56/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0975
# Epoch 57/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0970
# Epoch 58/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0965
# Epoch 59/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0960
# Epoch 60/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0955
# Epoch 61/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0951
# Epoch 62/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0946
# Epoch 63/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0942
# Epoch 64/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0938
# Epoch 65/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0934
# Epoch 66/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0930
# Epoch 67/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0927
# Epoch 68/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0923
# Epoch 69/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0920
# Epoch 70/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0916
# Epoch 71/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0913
# Epoch 72/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0910
# Epoch 73/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0907
# Epoch 74/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0904
# Epoch 75/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0901
# Epoch 76/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0898
# Epoch 77/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0895
# Epoch 78/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0892
# Epoch 79/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0890
# Epoch 80/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0887
# Epoch 81/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0885
# Epoch 82/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0882
# Epoch 83/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0879
# Epoch 84/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0877
# Epoch 85/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0875
# Epoch 86/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0872
# Epoch 87/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0870
# Epoch 88/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0868
# Epoch 89/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0866
# Epoch 90/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0864
# Epoch 91/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0861
# Epoch 92/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0859
# Epoch 93/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0857
# Epoch 94/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0855
# Epoch 95/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0853
# Epoch 96/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0851
# Epoch 97/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0849
# Epoch 98/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0847
# Epoch 99/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0845
# Epoch 100/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0843
# Epoch 101/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0841
# Epoch 102/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0839
# Epoch 103/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0836
# Epoch 104/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0834
# Epoch 105/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0832
# Epoch 106/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0830
# Epoch 107/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0828
# Epoch 108/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0825
# Epoch 109/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0823
# Epoch 110/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0821
# Epoch 111/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0818
# Epoch 112/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0816
# Epoch 113/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0813
# Epoch 114/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0811
# Epoch 115/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0808
# Epoch 116/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0806
# Epoch 117/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0804
# Epoch 118/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0801
# Epoch 119/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0799
# Epoch 120/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0797
# Epoch 121/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0794
# Epoch 122/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0792
# Epoch 123/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0790
# Epoch 124/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0788
# Epoch 125/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0786
# Epoch 126/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0784
# Epoch 127/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0782
# Epoch 128/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0780
# Epoch 129/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0778
# Epoch 130/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0776
# Epoch 131/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0774
# Epoch 132/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0772
# Epoch 133/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0771
# Epoch 134/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0769
# Epoch 135/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0767
# Epoch 136/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0766
# Epoch 137/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0764
# Epoch 138/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0762
# Epoch 139/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0761
# Epoch 140/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0759
# Epoch 141/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0757
# Epoch 142/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0756
# Epoch 143/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0754
# Epoch 144/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0753
# Epoch 145/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0751
# Epoch 146/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0749
# Epoch 147/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0748
# Epoch 148/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0746
# Epoch 149/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0745
# Epoch 150/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0743
# Epoch 151/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0742
# Epoch 152/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0741
# Epoch 153/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0739
# Epoch 154/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0738
# Epoch 155/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0736
# Epoch 156/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0735
# Epoch 157/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0734
# Epoch 158/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0732
# Epoch 159/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0731
# Epoch 160/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0730
# Epoch 161/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0729
# Epoch 162/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0728
# Epoch 163/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0727
# Epoch 164/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0726
# Epoch 165/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0725
# Epoch 166/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0724
# Epoch 167/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0723
# Epoch 168/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0722
# Epoch 169/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0721
# Epoch 170/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0720
# Epoch 171/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0719
# Epoch 172/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0718
# Epoch 173/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0717
# Epoch 174/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0716
# Epoch 175/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0715
# Epoch 176/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0715
# Epoch 177/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0714
# Epoch 178/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0713
# Epoch 179/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0712
# Epoch 180/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0711
# Epoch 181/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0710
# Epoch 182/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0710
# Epoch 183/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0709
# Epoch 184/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0708
# Epoch 185/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0707
# Epoch 186/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0707
# Epoch 187/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0706
# Epoch 188/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0705
# Epoch 189/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0705
# Epoch 190/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0704
# Epoch 191/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0703
# Epoch 192/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0703
# Epoch 193/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0702
# Epoch 194/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0702
# Epoch 195/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0701
# Epoch 196/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0701
# Epoch 197/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0700
# Epoch 198/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0699
# Epoch 199/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0699
# Epoch 200/200
# 60/60 [==============================] - 0s 6ms/step - loss: 0.0698

# %%
plt.figure(figsize=(10, 9.5))
for i, comp in enumerate(latent_ncdr.get_weights()[0].T):
    plt.subplot(10, 10, i + 1)
    plt.imshow(comp.reshape((28, 28)), cmap=plt.cm.gray_r,
               interpolation='nearest')
    plt.xticks(())
    plt.yticks(())
plt.subplots_adjust(0.08, 0.02, 0.92, 0.85, 0.08, 0.23)
plt.savefig('ch.10.ae.100.components.mnist.png', bbox_inches='tight', dpi=350)

# %%
plt.figure(figsize=(10, 2))
for i in range(10):
  plt.subplot(2, 10, i+1)
  plt.imshow(x_test[i].reshape((28, 28)), cmap='gray')
  plt.xticks(())
  plt.yticks(())
  
X_ = autoencoder.predict(x_test[:10])
for i in range(10):
  plt.subplot(2, 10, i+11)
  plt.imshow(X_[i].reshape((28, 28)), cmap='gray')
  plt.xticks(())
  plt.yticks(())
  
plt.subplots_adjust(0.08, 0.02, 0.92, 0.85, 0.08, 0.23)
plt.savefig('ch.10.ae.100.recons.mnist.png', bbox_inches='tight', dpi=350)
